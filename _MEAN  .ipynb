# %%
x = [1, 2, 3, 4, 5, 6, 7, 8, 9]   # List of numbers
mean = sum(x) / len(x)            # Calculating mean: sum of numbers / total count
print(mean)                       # Printing the mean value
# Out:
# 5.0

# %% [markdown]
# ## CALCULATING MEAN

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8, 9]   # List of numbers
mean = sum(x) / len(x)            # Calculating mean: sum of numbers / total count
print(mean)                       # Printing the mean value
# Out:
# 5.0

# %%
population=[150,160,170,165,155]
pop_mean=sum(population)/len(population)
print("population mean is:",pop_mean)
# Out:
# population mean is: 160.0

# %%
sample=[150,170,165]
sam_mean=sum(sample)/len(sample)
print("sample mean is:",sam_mean)
# Out:
# sample mean is: 161.66666666666666

# %% [markdown]
# ## USING NUMPY LIBRARY

# %%
import numpy as np
data=[10,20,30,40,50]
sample_mean=np.mean(data)
print("mean is the:",sample_mean)
# Out:
# mean is the: 30.0

# %% [markdown]
# ## USING STATISTICS

# %%
import statistics as st
data=[20,40,60,80,100]
mean_st=st.mean(data)
print("mean is the:",mean_st)
# Out:
# mean is the: 60

# %% [markdown]
# # DATA SET

# %%
mean_sepal_length=np.mean(iris["sepal_length"])
print("the mean of sepal length is ", mean_sepal_length)
# Out:
# the mean of sepal length is  5.843333333333334
